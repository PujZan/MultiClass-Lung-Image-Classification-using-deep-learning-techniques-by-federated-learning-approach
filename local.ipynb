# %%
import os
import numpy as np
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader
from torchvision import models, transforms
from PIL import Image
import matplotlib.pyplot as plt
from torchmetrics.classification import MulticlassAccuracy

# %%
# Set CUDA environment variable
os.environ['CUDA_LAUNCH_BLOCKING'] = '1'

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %%
torch.cuda.empty_cache()

# %%
if torch.cuda.is_available():
    print("CUDA is available!")
    print(f"CUDA Device Count: {torch.cuda.device_count()}")
    print(f"Current Device: {torch.cuda.current_device()}")
    print(f"Device Name: {torch.cuda.get_device_name(torch.cuda.current_device())}")
else:
    print("CUDA is not available.")
# Out:
# CUDA is available!
# CUDA Device Count: 1
# Current Device: 0
# Device Name: NVIDIA GeForce RTX 3060 Laptop GPU

# %%
# Define a custom ResNet model with added dropout and a fully connected layer
class CustomResNet(nn.Module):
    def __init__(self, num_classes):
        super(CustomResNet, self).__init__()
        self.model = models.resnet101(weights=models.ResNet101_Weights.IMAGENET1K_V2)
        self.model.fc = nn.Sequential(
            nn.Dropout(0.3),
            nn.Linear(self.model.fc.in_features, num_classes),
        )

    def forward(self, x):
        return self.model(x)

# %%
class LungImageDataset(Dataset):
    def __init__(self, dataset_folder, classes=None, transform=None):
        self.dataset_folder = dataset_folder
        self.transform = transform
        self.classes = classes
        self.data = self._load_data()

    def _load_data(self):
        data = []
        label_mapping = {class_name: idx for idx, class_name in enumerate(self.classes)}

        for class_name in self.classes:
            class_folder = os.path.join(self.dataset_folder, class_name)
            if os.path.isdir(class_folder):
                for img_name in os.listdir(class_folder):
                    img_path = os.path.join(class_folder, img_name)
                    if os.path.isfile(img_path):
                        data.append((img_path, label_mapping[class_name]))

        print(f"Loaded {len(data)} images from {self.dataset_folder} for classes: {self.classes}.")
        return data

    def __len__(self):
        return len(self.data)

    def __getitem__(self, idx):
        img_path, label = self.data[idx]
        image = Image.open(img_path).convert('RGB')
        if self.transform:
            image = self.transform(image)
        return image, label

# %%
def aggregate_model_params(global_model, clients, device):
    global_dict = global_model.state_dict()  # Ensure global model is on device
    client_dicts = [client[2].state_dict() for client in clients]  # Extract client models' state_dicts

    total_data_points = sum(len(client[0].dataset) for client in clients)  # Get total dataset size

    for key in global_dict.keys():
        weighted_sum = torch.zeros_like(global_dict[key], dtype=torch.float32).to(device)  # Move to device
        
        for client_data, client_dict in zip(clients, client_dicts):
            weight = len(client_data[0].dataset) / total_data_points  # Compute weight
            weighted_sum += client_dict[key].to(device).float() * weight  # Ensure tensors are on the same device

        global_dict[key] = weighted_sum.type(global_dict[key].dtype)  # Convert back to original dtype

    global_model.load_state_dict(global_dict)  # Load updated weights into the global model

# %%
def validate_global_model(model, val_loader, criterion, device, num_classes):
    model.eval()
    model.to(device)
    
    val_loss = 0.0
    all_labels = []
    all_preds = []

    with torch.no_grad():
        for images, labels in val_loader:
            images, labels = images.to(device), labels.to(device)
            outputs = model(images)
            loss = criterion(outputs, labels)
            val_loss += loss.item() * images.size(0)
            preds = torch.argmax(outputs, dim=1)

            all_labels.append(labels)
            all_preds.append(preds)

    all_labels = torch.cat(all_labels).cpu()
    all_preds = torch.cat(all_preds).cpu()

    accuracy_micro = MulticlassAccuracy(num_classes=num_classes, average='micro')(all_preds, all_labels).item()

    val_loss /= len(val_loader.dataset)
    print(f"Validation Loss: {val_loss:.4f}")
    print(f"Accuracy: {accuracy_micro:.4f}")

    return {"val_loss": val_loss, "accuracy": accuracy_micro}

# %%
def federated_train(global_model, criterion, clients, val_loader, device, num_classes, num_epochs=200, patience=20):
    best_accuracy = 0.0
    epochs_since_improvement = 0

    for epoch in range(num_epochs):
        print(f"\nFederated Epoch [{epoch + 1}/{num_epochs}]")
        global_model.train()
        epoch_client_losses = []
        epoch_client_accuracies = []

        for client_id, (client_data_loader, client_optimizer, client_model, client_scheduler) in enumerate(clients):
            client_model.load_state_dict(global_model.state_dict())
            client_model.to(device)
            client_model.train()
            running_loss = 0.0
            correct_train = 0
            total_train = 0

            for images, labels in client_data_loader:
                images, labels = images.to(device), labels.to(device)
                client_optimizer.zero_grad()
                outputs = client_model(images)
                loss = criterion(outputs, labels)
                loss.backward()
                client_optimizer.step()
                running_loss += loss.item() * images.size(0)
                _, predicted = torch.max(outputs, 1)
                correct_train += (predicted == labels).sum().item()
                total_train += labels.size(0)

            client_loss = running_loss / total_train if total_train > 0 else 0.0
            client_accuracy = correct_train / total_train if total_train > 0 else 0.0
            epoch_client_losses.append(client_loss)
            epoch_client_accuracies.append(client_accuracy)
            print(f"Client {client_id + 1}: Loss: {client_loss:.4f}, Accuracy: {client_accuracy:.4f}")

        avg_loss = np.mean(epoch_client_losses)
        avg_accuracy = np.mean(epoch_client_accuracies)
        print(f"Average Client Loss: {avg_loss:.4f}")
        print(f"Average Client Accuracy: {avg_accuracy:.4f}")
        aggregate_model_params(global_model, clients,device)
        metrics = validate_global_model(global_model, val_loader, criterion, device, num_classes)
        
        if metrics["accuracy"] > best_accuracy:
            best_accuracy = metrics["accuracy"]
            torch.save(global_model.state_dict(), "model.pth")
            print("Saved the best model!")
        else:
            epochs_since_improvement += 1
            if epochs_since_improvement >= patience:
                print("Early stopping triggered!")
                break

# %%
def main():
    train_folder = "C:\\Users\\Acer\\Desktop\\Model\\Split\\train"
    val_folder = "C:\\Users\\Acer\\Desktop\\Model\\Split\\val"
    test_folder = "C:\\Users\\Acer\\Desktop\\Model\\Split\\test"

    client_class_groups = {
        1: ['Atelectasis','Covid19','Emphysema','Consolidation'],
        2: ['Cardiomegaly','Infiltration','Nodule'],
        3: ['Pneumonia','NORMAL','Pneumothorax']
    }

    train_transform = transforms.Compose([
        transforms.Resize((224, 224)),
        transforms.RandomHorizontalFlip(),
        transforms.RandomRotation(15),  
        transforms.ToTensor(),
        transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225]),
    ])

    val_test_transform = transforms.Compose([
        transforms.Resize((224, 224)),
        transforms.ToTensor(),
        transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225]),
    ])

    clients = []
    for client_id, classes in client_class_groups.items():
        client_train_dataset = LungImageDataset(dataset_folder=train_folder,classes=classes,transform=train_transform)
        client_val_dataset = LungImageDataset(dataset_folder=val_folder,classes=classes,transform=val_test_transform)
        client_test_dataset = LungImageDataset(dataset_folder=test_folder,classes=classes,transform=val_test_transform)

        client_train_loader = DataLoader(client_train_dataset, batch_size=32, shuffle=True)
        client_val_loader = DataLoader(client_val_dataset, batch_size=32, shuffle=False)
        client_test_loader = DataLoader(client_test_dataset, batch_size=32, shuffle=False)

        client_model = CustomResNet(num_classes=10)
        client_optimizer = optim.Adam(client_model.parameters(), lr=0.001)
        client_scheduler = optim.lr_scheduler.StepLR(client_optimizer, step_size=5, gamma=0.1)
        clients.append((client_train_loader, client_optimizer, client_model, None))

    global_model = CustomResNet(num_classes=10).to(device)
    criterion = nn.CrossEntropyLoss()
    federated_train(global_model, criterion, clients, client_train_loader, device, 10, num_epochs=50)

if __name__ == "__main__":
    main()
# Out:
# Loaded 13692 images from C:\Users\Acer\Desktop\Model\Split\train for classes: ['Atelectasis', 'Covid19', 'Emphysema', 'Consolidation'].
# Loaded 2935 images from C:\Users\Acer\Desktop\Model\Split\val for classes: ['Atelectasis', 'Covid19', 'Emphysema', 'Consolidation'].
# Loaded 2937 images from C:\Users\Acer\Desktop\Model\Split\test for classes: ['Atelectasis', 'Covid19', 'Emphysema', 'Consolidation'].
# Loaded 10586 images from C:\Users\Acer\Desktop\Model\Split\train for classes: ['Cardiomegaly', 'Infiltration', 'Nodule'].
# Loaded 2269 images from C:\Users\Acer\Desktop\Model\Split\val for classes: ['Cardiomegaly', 'Infiltration', 'Nodule'].
# Loaded 2271 images from C:\Users\Acer\Desktop\Model\Split\test for classes: ['Cardiomegaly', 'Infiltration', 'Nodule'].
# Loaded 10257 images from C:\Users\Acer\Desktop\Model\Split\train for classes: ['Pneumonia', 'NORMAL', 'Pneumothorax'].
# Loaded 2198 images from C:\Users\Acer\Desktop\Model\Split\val for classes: ['Pneumonia', 'NORMAL', 'Pneumothorax'].
# Loaded 2200 images from C:\Users\Acer\Desktop\Model\Split\test for classes: ['Pneumonia', 'NORMAL', 'Pneumothorax'].
#
# Federated Epoch [1/50]
# Client 1: Loss: 0.7785, Accuracy: 0.6773
# Client 2: Loss: 0.7516, Accuracy: 0.6639
# Client 3: Loss: 0.1841, Accuracy: 0.9382
# Average Client Loss: 0.5714
# Average Client Accuracy: 0.7598
# Validation Loss: 2.0874
# Accuracy: 0.3527
# Saved the best model!
#
# Federated Epoch [2/50]
# Client 1: Loss: 0.6754, Accuracy: 0.7258
# Client 2: Loss: 0.6838, Accuracy: 0.7007
# Client 3: Loss: 0.1495, Accuracy: 0.9480
# Average Client Loss: 0.5029
# Average Client Accuracy: 0.7915
# Validation Loss: 1.4517
# Accuracy: 0.5856
# Saved the best model!
#
# Federated Epoch [3/50]
# Client 1: Loss: 0.6002, Accuracy: 0.7642
# Client 2: Loss: 0.6244, Accuracy: 0.7284
# Client 3: Loss: 0.1088, Accuracy: 0.9615
# Average Client Loss: 0.4445
# Average Client Accuracy: 0.8180
# Validation Loss: 1.0541
# Accuracy: 0.6354
# Saved the best model!
#
# Federated Epoch [4/50]
# Client 1: Loss: 0.5508, Accuracy: 0.7851
# Client 2: Loss: 0.5909, Accuracy: 0.7457
# Client 3: Loss: 0.0978, Accuracy: 0.9672
# Average Client Loss: 0.4132
# Average Client Accuracy: 0.8327
# Validation Loss: 0.9798
# Accuracy: 0.5988
#
# Federated Epoch [5/50]
# Client 1: Loss: 0.5275, Accuracy: 0.7930
# Client 2: Loss: 0.5737, Accuracy: 0.7535
# Client 3: Loss: 0.1023, Accuracy: 0.9650
# Average Client Loss: 0.4012
# Average Client Accuracy: 0.8372
# Validation Loss: 0.9673
# Accuracy: 0.6102
#
# Federated Epoch [6/50]
# Client 1: Loss: 0.5077, Accuracy: 0.8035
# Client 2: Loss: 0.5595, Accuracy: 0.7590
# Client 3: Loss: 0.0721, Accuracy: 0.9771
# Average Client Loss: 0.3798
# Average Client Accuracy: 0.8465
# Validation Loss: 0.7365
# Accuracy: 0.7494
# Saved the best model!
#
# Federated Epoch [7/50]
# Client 1: Loss: 0.4713, Accuracy: 0.8157
# Client 2: Loss: 0.5333, Accuracy: 0.7733
# Client 3: Loss: 0.0782, Accuracy: 0.9729
# Average Client Loss: 0.3609
# Average Client Accuracy: 0.8539
# Validation Loss: 0.6532
# Accuracy: 0.7258
#
# Federated Epoch [8/50]
# Client 1: Loss: 0.4579, Accuracy: 0.8203
# Client 2: Loss: 0.5254, Accuracy: 0.7740
# Client 3: Loss: 0.0744, Accuracy: 0.9747
# Average Client Loss: 0.3526
# Average Client Accuracy: 0.8563
# Validation Loss: 0.6946
# Accuracy: 0.6804
#
# Federated Epoch [9/50]
# Client 1: Loss: 0.4329, Accuracy: 0.8322
# Client 2: Loss: 0.5044, Accuracy: 0.7875
# Client 3: Loss: 0.0713, Accuracy: 0.9762
# Average Client Loss: 0.3362
# Average Client Accuracy: 0.8653
# Validation Loss: 0.5798
# Accuracy: 0.7134
#
# Federated Epoch [10/50]
# Client 1: Loss: 0.4239, Accuracy: 0.8304
# Client 2: Loss: 0.5037, Accuracy: 0.7860
# Client 3: Loss: 0.0662, Accuracy: 0.9775
# Average Client Loss: 0.3313
# Average Client Accuracy: 0.8646
# Validation Loss: 0.4425
# Accuracy: 0.8429
# Saved the best model!
#
# Federated Epoch [11/50]
# Client 1: Loss: 0.3955, Accuracy: 0.8455
# Client 2: Loss: 0.4846, Accuracy: 0.7962
# Client 3: Loss: 0.0678, Accuracy: 0.9760
# Average Client Loss: 0.3160
# Average Client Accuracy: 0.8726
# Validation Loss: 0.5962
# Accuracy: 0.7305
#
# Federated Epoch [12/50]
# Client 1: Loss: 0.3800, Accuracy: 0.8515
# Client 2: Loss: 0.4720, Accuracy: 0.7995
# Client 3: Loss: 0.0613, Accuracy: 0.9813
# Average Client Loss: 0.3044
# Average Client Accuracy: 0.8774
# Validation Loss: 0.5039
# Accuracy: 0.8161
#
# Federated Epoch [13/50]
# Client 1: Loss: 0.3723, Accuracy: 0.8556
# Client 2: Loss: 0.4609, Accuracy: 0.8048
# Client 3: Loss: 0.0661, Accuracy: 0.9780
# Average Client Loss: 0.2998
# Average Client Accuracy: 0.8795
# Validation Loss: 0.4609
# Accuracy: 0.8493
# Saved the best model!
#
# Federated Epoch [14/50]
# Client 1: Loss: 0.3421, Accuracy: 0.8674
# Client 2: Loss: 0.4570, Accuracy: 0.8040
# Client 3: Loss: 0.0562, Accuracy: 0.9803
# Average Client Loss: 0.2851
# Average Client Accuracy: 0.8839
# Validation Loss: 0.3990
# Accuracy: 0.8439
#
# Federated Epoch [15/50]
# Client 1: Loss: 0.3338, Accuracy: 0.8625
# Client 2: Loss: 0.4566, Accuracy: 0.8080
# Client 3: Loss: 0.0593, Accuracy: 0.9793
# Average Client Loss: 0.2832
# Average Client Accuracy: 0.8833
# Validation Loss: 0.3788
# Accuracy: 0.8754
# Saved the best model!
#
# Federated Epoch [16/50]
# Client 1: Loss: 0.3087, Accuracy: 0.8815
# Client 2: Loss: 0.4425, Accuracy: 0.8109
# Client 3: Loss: 0.0550, Accuracy: 0.9804
# Average Client Loss: 0.2687
# Average Client Accuracy: 0.8909
# Validation Loss: 0.2881
# Accuracy: 0.9168
# Saved the best model!
#
# Federated Epoch [17/50]
# Client 1: Loss: 0.3056, Accuracy: 0.8821
# Client 2: Loss: 0.4285, Accuracy: 0.8224
# Client 3: Loss: 0.0486, Accuracy: 0.9835
# Average Client Loss: 0.2609
# Average Client Accuracy: 0.8960
# Validation Loss: 0.3924
# Accuracy: 0.8350
#
# Federated Epoch [18/50]
# Client 1: Loss: 0.2805, Accuracy: 0.8922
# Client 2: Loss: 0.4154, Accuracy: 0.8253
# Client 3: Loss: 0.0493, Accuracy: 0.9820
# Average Client Loss: 0.2484
# Average Client Accuracy: 0.8998
# Validation Loss: 0.3095
# Accuracy: 0.8962
#
# Federated Epoch [19/50]
# Client 1: Loss: 0.2724, Accuracy: 0.8947
# Client 2: Loss: 0.4120, Accuracy: 0.8262
# Client 3: Loss: 0.0454, Accuracy: 0.9846
# Average Client Loss: 0.2432
# Average Client Accuracy: 0.9018
# Validation Loss: 0.3283
# Accuracy: 0.8765
#
# Federated Epoch [20/50]
# Client 1: Loss: 0.2638, Accuracy: 0.8986
# Client 2: Loss: 0.4028, Accuracy: 0.8308
# Client 3: Loss: 0.0452, Accuracy: 0.9848
# Average Client Loss: 0.2373
# Average Client Accuracy: 0.9047
# Validation Loss: 0.3408
# Accuracy: 0.8685
#
# Federated Epoch [21/50]
# Client 1: Loss: 0.2595, Accuracy: 0.9028
# Client 2: Loss: 0.3926, Accuracy: 0.8322
# Client 3: Loss: 0.0472, Accuracy: 0.9849
# Average Client Loss: 0.2331
# Average Client Accuracy: 0.9066
# Validation Loss: 0.2662
# Accuracy: 0.9149
#
# Federated Epoch [22/50]
# Client 1: Loss: 0.2338, Accuracy: 0.9108
# Client 2: Loss: 0.3857, Accuracy: 0.8374
# Client 3: Loss: 0.0450, Accuracy: 0.9849
# Average Client Loss: 0.2215
# Average Client Accuracy: 0.9110
# Validation Loss: 0.3313
# Accuracy: 0.8648
#
# Federated Epoch [23/50]
# Client 1: Loss: 0.2148, Accuracy: 0.9168
# Client 2: Loss: 0.3735, Accuracy: 0.8384
# Client 3: Loss: 0.0409, Accuracy: 0.9860
# Average Client Loss: 0.2098
# Average Client Accuracy: 0.9137
# Validation Loss: 0.2290
# Accuracy: 0.9347
# Saved the best model!
#
# Federated Epoch [24/50]
# Client 1: Loss: 0.2031, Accuracy: 0.9224
# Client 2: Loss: 0.3706, Accuracy: 0.8395
# Client 3: Loss: 0.0412, Accuracy: 0.9859
# Average Client Loss: 0.2050
# Average Client Accuracy: 0.9159
# Validation Loss: 0.3392
# Accuracy: 0.8684
#
# Federated Epoch [25/50]
# Client 1: Loss: 0.2059, Accuracy: 0.9221
# Client 2: Loss: 0.3613, Accuracy: 0.8522
# Client 3: Loss: 0.0437, Accuracy: 0.9829
# Average Client Loss: 0.2036
# Average Client Accuracy: 0.9191
# Validation Loss: 0.3022
# Accuracy: 0.8846
#
# Federated Epoch [26/50]
# Client 1: Loss: 0.1873, Accuracy: 0.9287
# Client 2: Loss: 0.3475, Accuracy: 0.8551
# Client 3: Loss: 0.0402, Accuracy: 0.9864
# Average Client Loss: 0.1917
# Average Client Accuracy: 0.9234
# Validation Loss: 0.1793
# Accuracy: 0.9478
# Saved the best model!
#
# Federated Epoch [27/50]
# Client 1: Loss: 0.1785, Accuracy: 0.9329
# Client 2: Loss: 0.3474, Accuracy: 0.8542
# Client 3: Loss: 0.0402, Accuracy: 0.9870
# Average Client Loss: 0.1887
# Average Client Accuracy: 0.9247
# Validation Loss: 0.2059
# Accuracy: 0.9309
#
# Federated Epoch [28/50]
# Client 1: Loss: 0.1730, Accuracy: 0.9329
# Client 2: Loss: 0.3354, Accuracy: 0.8592
# Client 3: Loss: 0.0403, Accuracy: 0.9867
# Average Client Loss: 0.1829
# Average Client Accuracy: 0.9263
# Validation Loss: 0.1615
# Accuracy: 0.9548
# Saved the best model!
#
# Federated Epoch [29/50]
# Client 1: Loss: 0.1586, Accuracy: 0.9416
# Client 2: Loss: 0.3304, Accuracy: 0.8615
# Client 3: Loss: 0.0350, Accuracy: 0.9877
# Average Client Loss: 0.1746
# Average Client Accuracy: 0.9303
# Validation Loss: 0.3061
# Accuracy: 0.8832
#
# Federated Epoch [30/50]
# Client 1: Loss: 0.1552, Accuracy: 0.9439
# Client 2: Loss: 0.3196, Accuracy: 0.8665
# Client 3: Loss: 0.0324, Accuracy: 0.9880
# Average Client Loss: 0.1690
# Average Client Accuracy: 0.9328
# Validation Loss: 0.1563
# Accuracy: 0.9524
#
# Federated Epoch [31/50]
# Client 1: Loss: 0.1464, Accuracy: 0.9478
# Client 2: Loss: 0.3139, Accuracy: 0.8708
# Client 3: Loss: 0.0346, Accuracy: 0.9870
# Average Client Loss: 0.1650
# Average Client Accuracy: 0.9352
# Validation Loss: 0.2051
# Accuracy: 0.9242
# Early stopping triggered!
